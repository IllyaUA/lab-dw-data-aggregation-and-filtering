# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing first data cleaning, formatting, and structuring.

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
import numpy as np
import pandas as pd
import cleaners

#read data
dfq=pd.read_csv("marketing_customer_analysis.txt")
display(dfq.shape)
dfq.head()
# Out:
# (10910, 26)
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# 2. Using the original dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
#define cleaning parameters
state_mapping = {
        'Alabama': 'AL',
        'Alaska': 'AK',
        'Arizona': 'AZ',
        'Arkansas': 'AR',
        'California': 'CA',
        'Colorado': 'CO',
        'Connecticut': 'CT',
        'Delaware': 'DE',
        'Florida': 'FL',
        'Georgia': 'GA',
        'Hawaii': 'HI',
        'Idaho': 'ID',
        'Illinois': 'IL',
        'Indiana': 'IN',
        'Iowa': 'IA',
        'Kansas': 'KS',
        'Kentucky': 'KY',
        'Louisiana': 'LA',
        'Maine': 'ME',
        'Maryland': 'MD',
        'Massachusetts': 'MA',
        'Michigan': 'MI',
        'Minnesota': 'MN',
        'Mississippi': 'MS',
        'Missouri': 'MO',
        'Montana': 'MT',
        'Nebraska': 'NE',
        'Nevada': 'NV',
        'New Hampshire': 'NH',
        'New Jersey': 'NJ',
        'New Mexico': 'NM',
        'New York': 'NY',
        'North Carolina': 'NC',
        'North Dakota': 'ND',
        'Ohio': 'OH',
        'Oklahoma': 'OK',
        'Oregon': 'OR',
        'Pennsylvania': 'PA',
        'Rhode Island': 'RI',
        'South Carolina': 'SC',
        'South Dakota': 'SD',
        'Tennessee': 'TN',
        'Texas': 'TX',
        'Utah': 'UT',
        'Vermont': 'VT',
        'Virginia': 'VA',
        'Washington': 'WA',
        'West Virginia': 'WV',
        'Wisconsin': 'WI',
        'Wyoming': 'WY'
}

threshold= 0.75     # Treshold for the match ratio

mappings = {
    "education": {"Bachelors": "Bachelor", "High School": "High School", "Doctorate": "Doctorate"},
    "customer_lifetime_value": {"%": ""},
    "vehicle_class": {"Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car": "Luxury"}
}

# %%
#drop by "Customer"
df=cleaners.drop_null_by_column(dfq, ["Customer","Customer Lifetime Value"])
df.shape
# Out:
# (10910, 26)

# %%
#duplicates dealing
duplicate_rows = df[df.duplicated()]

# Display the duplicate rows
print(duplicate_rows)
df.drop_duplicates(subset=['Customer'],keep='first', inplace=True)
display(df.shape, df.head())

duplicate_rows = df[df.duplicated()]

# Display the duplicate rows
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Vehicle Type]
# Index: []
#
# [0 rows x 26 columns]
# (9134, 26)
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]
# Empty DataFrame
# Columns: [Unnamed: 0, Customer, State, Customer Lifetime Value, Response, Coverage, Education, Effective To Date, EmploymentStatus, Gender, Income, Location Code, Marital Status, Monthly Premium Auto, Months Since Last Claim, Months Since Policy Inception, Number of Open Complaints, Number of Policies, Policy Type, Policy, Renew Offer Type, Sales Channel, Total Claim Amount, Vehicle Class, Vehicle Size, Vehicle Type]
# Index: []
#
# [0 rows x 26 columns]

# %%
#here we standardize column names
df=cleaners.cols_names(df, "st","state") 

display(df.shape, df.head(),df.tail())
# Out:
# (9134, 26)
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 10903     Basic               College            1/7/11         Employed
# 10904     Basic  High School or Below           2/24/11       Unemployed
# 10906     Basic               College            1/6/11         Employed
# 10907  Extended              Bachelor            2/6/11         Employed
# 10908   Premium               College           2/13/11         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 10903      M  ...                        4.0                  1
# 10904      M  ...                        0.0                  2
# 10906      F  ...                        0.0                  6
# 10907      F  ...                        0.0                  2
# 10908      F  ...                        4.0                  6
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 10903   Personal Auto   Personal L2            Offer2         Branch
# 10904   Personal Auto   Personal L2            Offer1         Branch
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10907  Corporate Auto  Corporate L3            Offer1            Web
# 10908   Personal Auto   Personal L1            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 10903          355.200000   Two-Door Car      Medsize            A
# 10904          897.600000     Luxury SUV      Medsize            A
# 10906          273.018929  Four-Door Car      Medsize            A
# 10907          381.306996     Luxury SUV      Medsize          NaN
# 10908          618.288849            SUV      Medsize            A
#
# [5 rows x 26 columns]

# %%
if "unnamed:_0" in df.columns:
    df = df.drop(columns=["unnamed:_0"])

df.reset_index()

df=cleaners.genders(df) #fix genders
display(df.shape, df.head())
# Out:
# (9134, 25)
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# 1                       0.0                  1   Personal Auto   Personal L3
# 2                       0.0                  2   Personal Auto   Personal L3
# 3                       0.0                  2  Corporate Auto  Corporate L3
# 4                       NaN                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 25 columns]

# %%
# Convert the numeric values to integers, treating NaN as 0
df['state'] = df['state'].fillna("NaN").astype(str) #to fix strange TypeError
df=cleaners.fix_abbreviations(df, state_mapping, "state", 0.7)
df.head()
# Out:
#   customer state  customer_lifetime_value response  coverage education  \
# 0  DK49336    AZ              4809.216960       No     Basic   College
# 1  KX64629    CA              2228.525238       No     Basic   College
# 2  LZ68649    WA             14947.917300       No     Basic  Bachelor
# 3  XL78013    OR             22332.439460      Yes  Extended   College
# 4  QA50777    OR              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  9  Corporate Auto  Corporate L3
# 1                         0                  1   Personal Auto   Personal L3
# 2                         0                  2   Personal Auto   Personal L3
# 3                         0                  2  Corporate Auto  Corporate L3
# 4                         0                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 25 columns]

# %%
#customerlife_time fixing
df=df.dropna(subset=['customer_lifetime_value'])
#df=df.dropna(subset=['number_of_open_complaints'])
df['customer_lifetime_value'] = df['customer_lifetime_value'].astype('float')

display(df.shape, df.head())
# Out:
# (9134, 25)
#   customer state  customer_lifetime_value response  coverage education  \
# 0  DK49336    AZ              4809.216960       No     Basic   College
# 1  KX64629    CA              2228.525238       No     Basic   College
# 2  LZ68649    WA             14947.917300       No     Basic  Bachelor
# 3  XL78013    OR             22332.439460      Yes  Extended   College
# 4  QA50777    OR              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  9  Corporate Auto  Corporate L3
# 1                         0                  1   Personal Auto   Personal L3
# 2                         0                  2   Personal Auto   Personal L3
# 3                         0                  2  Corporate Auto  Corporate L3
# 4                         0                  7   Personal Auto   Personal L2
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 25 columns]

# %%
#open complains
df["number_of_open_complaints"] = pd.to_numeric(df["number_of_open_complaints"], errors="coerce").fillna(0).astype("int")

df
# Out:
#       customer state  customer_lifetime_value response  coverage  \
# 0      DK49336    AZ              4809.216960       No     Basic
# 1      KX64629    CA              2228.525238       No     Basic
# 2      LZ68649    WA             14947.917300       No     Basic
# 3      XL78013    OR             22332.439460      Yes  Extended
# 4      QA50777    OR              9025.067525       No   Premium
# ...        ...   ...                      ...      ...       ...
# 10903  SU71163    AZ              2771.663013       No     Basic
# 10904  QI63521    NV             19228.463620       No     Basic
# 10906  KX53892    OR              5259.444853       No     Basic
# 10907  TL39050    AZ             23893.304100       No  Extended
# 10908  WA60547    CA             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 0                   College           2/18/11         Employed      M   48029
# 1                   College           1/18/11       Unemployed      F       0
# 2                  Bachelor           2/10/11         Employed      M   22139
# 3                   College           1/11/11         Employed      M   49078
# 4                  Bachelor           1/17/11    Medical Leave      F   23675
# ...                     ...               ...              ...    ...     ...
# 10903               College            1/7/11         Employed      M   59855
# 10904  High School or Below           2/24/11       Unemployed      M       0
# 10906               College            1/6/11         Employed      F   61146
# 10907              Bachelor            2/6/11         Employed      F   39837
# 10908               College           2/13/11         Employed      F   64195
#
#        ... number_of_open_complaints number_of_policies     policy_type  \
# 0      ...                         0                  9  Corporate Auto
# 1      ...                         0                  1   Personal Auto
# 2      ...                         0                  2   Personal Auto
# 3      ...                         0                  2  Corporate Auto
# 4      ...                         0                  7   Personal Auto
# ...    ...                       ...                ...             ...
# 10903  ...                         4                  1   Personal Auto
# 10904  ...                         0                  2   Personal Auto
# 10906  ...                         0                  6   Personal Auto
# 10907  ...                         0                  2  Corporate Auto
# 10908  ...                         4                  6   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10903   Personal L2            Offer2         Branch          355.200000
# 10904   Personal L2            Offer1         Branch          897.600000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10903   Two-Door Car      Medsize            A
# 10904         Luxury      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907         Luxury      Medsize          NaN
# 10908            SUV      Medsize            A
#
# [9134 rows x 25 columns]

# %%
#standardize values of Cars, education
df=cleaners.standardize_column_values(df, mappings)
df
# Out:
#       customer state  customer_lifetime_value response  coverage  \
# 0      DK49336    AZ              4809.216960       No     Basic
# 1      KX64629    CA              2228.525238       No     Basic
# 2      LZ68649    WA             14947.917300       No     Basic
# 3      XL78013    OR             22332.439460      Yes  Extended
# 4      QA50777    OR              9025.067525       No   Premium
# ...        ...   ...                      ...      ...       ...
# 10903  SU71163    AZ              2771.663013       No     Basic
# 10904  QI63521    NV             19228.463620       No     Basic
# 10906  KX53892    OR              5259.444853       No     Basic
# 10907  TL39050    AZ             23893.304100       No  Extended
# 10908  WA60547    CA             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 0                   College           2/18/11         Employed      M   48029
# 1                   College           1/18/11       Unemployed      F       0
# 2                  Bachelor           2/10/11         Employed      M   22139
# 3                   College           1/11/11         Employed      M   49078
# 4                  Bachelor           1/17/11    Medical Leave      F   23675
# ...                     ...               ...              ...    ...     ...
# 10903               College            1/7/11         Employed      M   59855
# 10904  High School or Below           2/24/11       Unemployed      M       0
# 10906               College            1/6/11         Employed      F   61146
# 10907              Bachelor            2/6/11         Employed      F   39837
# 10908               College           2/13/11         Employed      F   64195
#
#        ... number_of_open_complaints number_of_policies     policy_type  \
# 0      ...                         0                  9  Corporate Auto
# 1      ...                         0                  1   Personal Auto
# 2      ...                         0                  2   Personal Auto
# 3      ...                         0                  2  Corporate Auto
# 4      ...                         0                  7   Personal Auto
# ...    ...                       ...                ...             ...
# 10903  ...                         4                  1   Personal Auto
# 10904  ...                         0                  2   Personal Auto
# 10906  ...                         0                  6   Personal Auto
# 10907  ...                         0                  2  Corporate Auto
# 10908  ...                         4                  6   Personal Auto
#
#              policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10903   Personal L2            Offer2         Branch          355.200000
# 10904   Personal L2            Offer1         Branch          897.600000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10903   Two-Door Car      Medsize            A
# 10904         Luxury      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907         Luxury      Medsize          NaN
# 10908            SUV      Medsize            A
#
# [9134 rows x 25 columns]

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
#customers per state
customers_per_state = df.groupby("state")["customer"].nunique()
print(customers_per_state)
# Out:
# state
# AZ     1655
# CA     3035
# NV      863
# NaN     290
# OR     2517
# WA      774
# Name: customer, dtype: int64

# %%
#filter states with > 500 customers
over500 = customers_per_state[customers_per_state > 500]
over500=over500.sort_values(ascending=False) # sorting by number 
print(over500)
#sorting by states alphabetically

over500_sorted = over500.sort_index()
print(over500_sorted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #filter states with > 500 customers
# ----> 2 over500 = customers_per_state[customers_per_state > 500]
#       3 over500=over500.sort_values(ascending=False) # sorting by number
#       4 print(over500)
#
# NameError: name 'customers_per_state' is not defined

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
# Group by 'education_level' and 'gender' and calculate the max, min, and median customer lifetime values
agg_df = df.groupby(['education', 'gender'])['customer_lifetime_value'].agg(['max', 'min', 'median']).astype("int")#round(0)

print(agg_df)
# Out:
#                                max   min  median
# education            gender
# Bachelor             F       73225  1904    5678
#                      M       67907  1898    5555
# College              F       61850  1898    5621
#                      M       61134  1918    5989
# Doctor               F       44856  2395    5332
#                      M       32677  2267    5620
# High School or Below F       55277  2144    6044
#                      M       83325  1940    6176
# Master               F       51016  2417    5801
#                      M       50568  2272    5617

# %%
#sort by median
agg_df_sorted = agg_df.sort_values(by='median', ascending=False)
print(agg_df_sorted)

#sort by gender
#agg_df_sorted = agg_df.sort_index(1)
agg_df_sorted = agg_df.sort_values(by=['gender', 'median'], ascending=[True, False])
print(agg_df_sorted)
# Out:
#                                max   min  median
# education            gender
# High School or Below M       83325  1940    6176
#                      F       55277  2144    6044
# College              M       61134  1918    5989
# Master               F       51016  2417    5801
# Bachelor             F       73225  1904    5678
# College              F       61850  1898    5621
# Doctor               M       32677  2267    5620
# Master               M       50568  2272    5617
# Bachelor             M       67907  1898    5555
# Doctor               F       44856  2395    5332
#                                max   min  median
# education            gender
# High School or Below F       55277  2144    6044
# Master               F       51016  2417    5801
# Bachelor             F       73225  1904    5678
# College              F       61850  1898    5621
# Doctor               F       44856  2395    5332
# High School or Below M       83325  1940    6176
# College              M       61134  1918    5989
# Doctor               M       32677  2267    5620
# Master               M       50568  2272    5617
# Bachelor             M       67907  1898    5555

# %%
#Conclusion - this lab made me understand and practive much better! Tnx!

# %%
type(agg_df)
agg_df.groupby("gender")["median"].agg("sum")
# Out:
# gender
# F    28476
# M    28957
# Name: median, dtype: int32

# %%
#Gals are a bit smarter in median! :)

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month.
#
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
